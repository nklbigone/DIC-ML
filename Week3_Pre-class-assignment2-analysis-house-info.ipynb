# %% [markdown]
# ## [Problem 1] Obtaining a dataset

# %%
import pandas as pd
houses = pd.read_csv('train.csv')
houses
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
houses.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## [Problem 2] Investigating the dataset itself

# %% [markdown]
# The dataset contain a set of house features that can be consider when you determine the prices of the houses.
#
# **Dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.**

# %% [markdown]
# ## [Problem 3] Checking the data

# %%
print("Numerical data",len(houses.dtypes[Houses.dtypes != "object"].index))

print("text data",len(houses.dtypes[Houses.dtypes == "object"].index))
# Out:
# Numerical data 38
# text data 43

# %% [markdown]
# ### Column is the target variable this time

# %% [markdown]
# The target variable is **sales Price**

# %%
houses.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houses.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ### Check for missing values for each feature.

# %%
import missingno as msno
# %matplotlib inline

# %%
msno.matrix(houses)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Check the percentage of missing values.

# %%
total = houses.isnull().sum().sort_values(ascending=False)
percent = (total/houses.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total,percent], axis=1,keys=["Total","percent"])
missing_data.head(20)
# Out:
#               Total   percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Utilities         0  0.000000

# %% [markdown]
# ### Delete features (columns) that have 5 or more missing values

# %%
houses = houses.drop(missing_data[missing_data['Total'] > 5].index,1)
houses = houses.drop(houses.loc[houses['Electrical'].isnull()].index)
houses.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# ## [Problem 5] Researching terminology

# %% [markdown]
# **Skewness** is a measure of symmetry, or more precisely, the lack of symmetry. A distribution, or data set, is symmetric if it looks the same to the left and right of the center point.
#
# **Kurtosis** is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution. That is, data sets with high kurtosis tend to have heavy tails, or outliers.

# %% [markdown]
# ## [Problem 6] Confirming distribution

# %%
import seaborn as sns
sns.histplot(houses['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
print("Skewness: ", houses['SalePrice'].skew())
print("Kurtosis: ", houses['SalePrice'].kurt())
# Out:
# Skewness:  1.8819429948035529
# Kurtosis:  6.529263049673958

# %% [markdown]
# ### Perform a logarithmic transformation on the objective variable

# %%
import numpy as np
log_transformed_house = np.log(houses['SalePrice'])

# %%
sns.histplot(log_transformed_house)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
print("Skewness: ", log_transformed_house.skew())
print("Kurtosis: ", log_transformed_house.kurt())
# Out:
# Skewness:  0.12131775882415026
# Kurtosis:  0.806927847502148

# %% [markdown]
# ## [Problem 7] Confirming the correlation coefficient

# %% [markdown]
# #### Create a heat map of the correlation coefficient matrix and find the relationships with high correlation coefficients.

# %%
corrs = houses.corr()
plt.figure(figsize=(15, 10))
plt.title('Correlatiom coefficient matrix')
sns.heatmap(corrs, vmax=.8, square=True)
plt.show()

# %% [markdown]
# #### Select 10 features that have a high correlation with the target variable, and create a correlation coefficient matrix heat map for these.

# %%
corr_target = corrs[['SalePrice']].sort_values(by=['SalePrice'], ascending=False)
corr_target[1:11]
# Out:
#               SalePrice
# OverallQual    0.791069
# GrLivArea      0.708618
# GarageCars     0.640473
# GarageArea     0.623423
# TotalBsmtSF    0.613905
# 1stFlrSF       0.605968
# FullBath       0.560881
# TotRmsAbvGrd   0.533779
# YearBuilt      0.523273
# YearRemodAdd   0.507430

# %%
target_matrix = houses[corr_target[1:11].index]
display(target_matrix)
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0               7       1710           2         548          856       856
# 1               6       1262           2         460         1262      1262
# 2               7       1786           2         608          920       920
# 3               7       1717           3         642          756       961
# 4               8       2198           3         836         1145      1145
# ...           ...        ...         ...         ...          ...       ...
# 1455            6       1647           2         460          953       953
# 1456            6       2073           2         500         1542      2073
# 1457            7       2340           1         252         1152      1188
# 1458            5       1078           1         240         1078      1078
# 1459            5       1256           1         276         1256      1256
#
#       FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd
# ...

# %%
plt.subplots(figsize=(15,10))
plt.title('Correlatiom coefficient  matrix')
sns.heatmap(target_matrix.corr(), vmax=1, annot=True)
plt.show()

# %% [markdown]
# This features dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
# - YearBuilt: Original construction date<br>
# - 1stFlrSF: First Floor square feet<br>
# - FullBath: Full bathrooms above <br>
# - TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)<br>
# - GarageArea: Size of garage in square feet<br>
# - GarageCars: Size of garage in car capacity <br>
# - TotalBsmtSF: Total square feet of basement <br>
# - YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)<br>
# - OverallQual: Rates the overall material and finish of the house
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor

# %% [markdown]
# #### The 3 combinations with high Correlatiom coefficients with each other

# %% [markdown]
# - GarageArea and GarageCar = 0.88
# - 1stFlrSF and TotalBsmtSF = 0.82
# - GrLivArea andTotRmsAbvGrd = 0.83

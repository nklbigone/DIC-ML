# %% [markdown]
# ## [Problem 1] Linear function

# %%
import numpy as np

x_ndarray = np.arange(-50, 50.1, 0.1) 
y_ndarray = 0.5*x_ndarray + 1
x_ndarray, y_ndarray
# Out:
# (array([-50. , -49.9, -49.8, ...,  49.8,  49.9,  50. ]),
#  array([-24.  , -23.95, -23.9 , ...,  25.9 ,  25.95,  26.  ]))

# %% [markdown]
# ## [Problem 2] Array combination

# %%
xy_ndarray = np.stack((x_ndarray, y_ndarray),1)
xy_ndarray.shape, xy_ndarray
# Out:
# ((1001, 2),
#  array([[-50.  , -24.  ],
#         [-49.9 , -23.95],
#         [-49.8 , -23.9 ],
#         ...,
#         [ 49.8 ,  25.9 ],
#         [ 49.9 ,  25.95],
#         [ 50.  ,  26.  ]]))

# %% [markdown]
# ## [Problem 3] Find the gradient

# %%
dx = np.diff(x_ndarray)
dy = np.diff(y_ndarray)
slope = dy/dx
slope = slope.reshape(slope.shape[0],1)

# %%
slope.shape
# Out:
# (1000, 1)

# %% [markdown]
# ## [Problem 4] Draw a graph

# %%
import matplotlib.pyplot as plt
plt.xlabel("X")
plt.ylabel("gradient")
plt.title("linear function")
plt.plot(x_ndarray,y_ndarray, color='black' , linewidth=5)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.xlabel("X")
plt.ylabel("gradient")
plt.title("linear function")
plt.plot(x_ndarray[:-1],slope,color='yellow',linewidth=5)
plt.show()

# %% [markdown]
# ## [Problem 5] Python functionalization

# %%
def function1(x):
    y = 0.5*x + 1
    return y

def function2(x):
    y = x**2
    return y

def function3(x):
    y = 2*x**2 + 2**x
    return y

def function4(x):
    y = np.sin(x**0.5)
    return y

def compute_gradient(function,x_range=(-50, 50.1, 0.1)):
    array_x = np.arange(*x_range)
    array_y = function(array_x)
    
    array_xy = np.stack((array_x, array_y),-1)
    gradient = np.diff(array_y)/np.diff(array_x)
    
    return array_xy, gradient

# %%
array_xy1, gradient1 = compute_gradient(function1)

plt.xlabel("x")
plt.ylabel("gradient")
plt.title("linear function y = 0.5*x + 1")
plt.plot(array_xy1[:,0],array_xy1[:,1], color='blue')
plt.plot(array_xy1[:-1,0],gradient1, color='green',linestyle='dashed', linewidth=5, markersize=6)
plt.show()

# %%
array_xy2, gradient2 = compute_gradient(function2)

plt.xlabel("x")
plt.ylabel("gradient")
plt.title("linear function y = x**2")
plt.plot(array_xy2[:,0],array_xy2[:,1], color='blue')
plt.plot(array_xy2[:-1,0],gradient2, color='green',linestyle='dashed', linewidth=5, markersize=6)
plt.show()

# %%
array_xy3, gradient3 = compute_gradient(function3)

plt.xlabel("x")
plt.ylabel("gradient")
plt.title("linear function y = 2*x**2 + 2**x")
plt.plot(array_xy3[:,0],array_xy3[:,1], color='blue',  linewidth=5,)
plt.plot(array_xy3[:-1,0],gradient3, color='red', linewidth=5, markersize=6)
plt.show()

# %%
array_xy4, gradient4 = compute_gradient(function4,x_range=(0, 50.1, 0.1))


plt.xlabel("x")
plt.ylabel("gradient")
plt.title("linear function y = sin(x**0.5)")
plt.plot(array_xy4[:,0],array_xy4[:,1], color='blue',linewidth=5)
plt.plot(array_xy4[:-1,0],gradient4, color='green',linestyle='dashed', linewidth=5, markersize=6)
plt.show()

# %% [markdown]
# ## [Problem 6] Find the minimum value

# %%
def compute_gradient(function,x_range=(-50, 50.1, 0.1)):
    array_x = np.arange(*x_range)
    array_y = function(array_x)
    min_y_value = np.min(array_y)
    min_y_arg = np.argmin(array_y)
    array_xy = np.stack((array_x, array_y),-1)
    gradient = np.diff(array_y)/np.diff(array_x)
    
    return f'The minimum value of y for this function is {min_y_value} and its index is {min_y_arg}'

# %%
compute_gradient(function1)
# Out:
# 'The minimum value of y for this function is -24.0 and its index is 0'

# %%
compute_gradient(function2)
# Out:
# 'The minimum value of y for this function is 5.048709793414476e-25 and its index is 500'

# %%
compute_gradient(function3)
# Out:
# 'The minimum value of y for this function is 0.9505505632959851 and its index is 498'

# %%
compute_gradient(function4, x_range=(0, 50.1, 0.1))
# Out:
# 'The minimum value of y for this function is -0.9999997540298113 and its index is 222'
